# %%
import pandas as pd
import math
import random
import copy
import csv

# %%
# ============ parameters ============
# speed: 15 km/h = 0.25 km/min
SPEED = 15 
SPEED = SPEED / 60  # 0.25 km/min
MAX_CAPACITY = 140  # Maximum cargo volume for couriers

def compute_distance(lat1, lng1, lat2, lng2):
    R = 6378.137
    lat1_rad = math.radians(lat1)
    lat2_rad = math.radians(lat2)
    lng1_rad = math.radians(lng1)
    lng2_rad = math.radians(lng2)
    dlat = lat2_rad - lat1_rad
    dlng = lng2_rad - lng1_rad
    # Haversine 
    a = (math.sin(dlat / 2) ** 2
         + math.cos(lat1_rad) * math.cos(lat2_rad) * math.sin(dlng / 2) ** 2)
    c = 2 * math.asin(math.sqrt(a))
    distance = R * c
    return distance

def travel_time(distance_km):
    time_minutes = distance_km * 4.0
    return time_minutes

def service_time(num_packages):
    service_minutes = 3.0 * math.sqrt(num_packages) + 5.0
    return service_minutes

# ============ data structure ============
class Stop:
    def __init__(self, location_id, lat, lng, stop_type, 
                 order_id=None, packages=0,
                 earliest=0, latest=24*60,
                 paired_stop_id=None):
        """
        stop_type: "site", "delivery", or "shop"
        earliest, latest: time window constraints (in minutes from 08:00)
        paired_stop_id: for O2O, shop-stop and delivery-stop are paired
        """
        self.location_id = location_id
        self.lat = lat
        self.lng = lng
        self.stop_type = stop_type
        self.order_id = order_id
        self.packages = packages
        self.earliest = earliest  # earliest arrival time
        self.latest = latest      # latest arrival time (only for O2O delivery)
        self.arrival = None
        self.departure = None
        # If it's a shop stop, store the ID of the corresponding delivery stop, and vice versa
        self.paired_stop_id = paired_stop_id

class Route:
    def __init__(self, courier_id, start_stop):
        self.courier_id = courier_id
        self.stops = [start_stop]  # Start from site
        self.current_load = 0

    def total_time(self):
        if self.stops and self.stops[-1].departure is not None:
            return self.stops[-1].departure
        else:
            return 0
            
# ============ read data ============
def read_data():
    """
    Reads the following CSV files:
      - new_1.csv: Site data (Site_id, Lng, Lat)
      - new_2.csv: Delivery spot data (Spot_id, Lng, Lat)
      - new_3.csv: Shop data (Shop_id, Lng, Lat)
      - new_4.csv: E-commerce orders (Order_id, Spot_id, Site_id, Num)
      - new_5.csv: O2O orders (Order_id, Spot_id, Shop_id, Pickup_time, Delivery_time, Num)
      - new_6.csv: Courier list (Courier_id)
    Returns:
      A tuple of six DataFrames: (sites, spots, shops, ecommerce_orders, o2o_orders, couriers).
    """
    sites = pd.read_csv("./Dataset/new_1.csv")
    spots = pd.read_csv("./Dataset/new_2.csv")
    shops = pd.read_csv("./Dataset/new_3.csv")
    ecommerce_orders = pd.read_csv("./Dataset/new_4.csv")
    o2o_orders = pd.read_csv("./Dataset/new_5.csv")
    couriers = pd.read_csv("./Dataset/new_6.csv")
    return sites, spots, shops, ecommerce_orders, o2o_orders, couriers

# ============ Create Stop List ============
def build_stop_list(sites, spots, shops, ecommerce_orders, o2o_orders):
    """
    将电商订单 (site -> spot) 与 O2O 订单 (shop -> spot) 全部转换为 Stop 对象列表：
      - 对于电商订单，每笔订单创建两个 Stop：
          1) pickup_stop: 从网点 (site_id) 取货
          2) delivery_stop: 将包裹送至配送点 (spot_id)
      - 对于 O2O 订单，每笔订单也创建两个 Stop：
          1) shop_stop: 从商户 (shop_id) 取货
          2) delivery_stop: 将包裹送至配送点 (spot_id)
    """

    # ---------- 1) 构造网点 / 配送点 / 商户 坐标字典 ----------
    site_dict = {row['Site_id']: (row['Lat'], row['Lng']) for _, row in sites.iterrows()}
    spot_dict = {row['Spot_id']: (row['Lat'], row['Lng']) for _, row in spots.iterrows()}
    shop_dict = {row['Shop_id']: (row['Lat'], row['Lng']) for _, row in shops.iterrows()}

    all_stops = []

    # ---------- 2) 电商订单：site -> spot ----------
    # 题目要求：电商包裹在 8:00 前已到达网点，快递员须在 20:00 前送到消费者手中。
    # 因此我们简单地将 [earliest=0, latest=12*60=720] 分别赋给取货和送货节点。
    # （注意：0 表示相对 08:00 的分钟数，即 08:00 -> 0, 20:00 -> 720）
    for _, row in ecommerce_orders.iterrows():
        site_id = row['Site_id']
        spot_id = row['Spot_id']
        packages = row['Num']

        # 网点坐标
        site_lat, site_lng = site_dict[site_id]
        # 配送点坐标
        spot_lat, spot_lng = spot_dict[spot_id]

        # 创建取货节点 (pickup from site)
        pickup_stop = Stop(
            location_id = site_id,
            lat = site_lat,
            lng = site_lng,
            stop_type = "site",         # 或者你也可以用 "pickup" 表示
            order_id = row['Order_id'],
            packages = packages,
            earliest = 0,              # 8:00 开始即可取货
            latest = 12*60,            # 必须在 20:00 前取走（可自行决定是否需要更严格）
            paired_stop_id = None      # 稍后设置
        )

        # 创建送货节点 (delivery to spot)
        delivery_stop = Stop(
            location_id = spot_id,
            lat = spot_lat,
            lng = spot_lng,
            stop_type = "delivery",
            order_id = row['Order_id'],
            packages = packages,
            earliest = 0,              # 可随时送达
            latest = 12*60,            # 必须在 20:00 前送到
            paired_stop_id = None
        )

        # 互相关联，方便后续在插入或局部搜索时校验“先取后送”
        pickup_stop.paired_stop_id = delivery_stop.location_id
        delivery_stop.paired_stop_id = pickup_stop.location_id

        all_stops.append(pickup_stop)
        all_stops.append(delivery_stop)

    # ---------- 3) O2O 订单：shop -> spot ----------
    # 与电商订单类似，只是取货点变为 shop，且有明确的 Pickup_time / Delivery_time。
    def time_to_minutes(t_str):
        # 将形如 "11:00" 的时间转换为相对 08:00 的分钟数：11:00 -> (11*60 + 0) - (8*60) = 180
        hour, minute = map(int, t_str.split(":"))
        return hour * 60 + minute - 8 * 60

    for _, row in o2o_orders.iterrows():
        shop_id = row['Shop_id']
        spot_id = row['Spot_id']
        packages = row['Num']

        pickup_t = time_to_minutes(row['Pickup_time'])    # 不能早于该时间到达商户
        delivery_t = time_to_minutes(row['Delivery_time'])# 必须在该时间前送达

        # 商户坐标
        shop_lat, shop_lng = shop_dict[shop_id]
        # 配送点坐标
        spot_lat, spot_lng = spot_dict[spot_id]

        # 创建商户取货节点
        shop_stop = Stop(
            location_id = shop_id,
            lat = shop_lat,
            lng = shop_lng,
            stop_type = "shop",
            order_id = row['Order_id'],
            packages = packages,
            earliest = pickup_t,   # 不得早于 pickup_time
            latest = 12*60,        # 这里可以设置为 20:00 或更宽松
            paired_stop_id = None
        )

        # 创建送货节点
        delivery_stop = Stop(
            location_id = spot_id,
            lat = spot_lat,
            lng = spot_lng,
            stop_type = "delivery",
            order_id = row['Order_id'],
            packages = packages,
            earliest = 0,         # 可以随时送达
            latest = delivery_t,   # 必须在 delivery_time 之前送到
            paired_stop_id = None
        )

        shop_stop.paired_stop_id = delivery_stop.location_id
        delivery_stop.paired_stop_id = shop_stop.location_id

        all_stops.append(shop_stop)
        all_stops.append(delivery_stop)

    return all_stops

# ============ Initial solution construction (greedy insertion) ============
def initial_solution(sites, spots, shops, ecommerce_orders, o2o_orders, couriers):
    """
    仅以电商订单为例，采用贪心策略构造初始路线：
      1. 对每位快递员随机指定一个起始网点（取货点）。
      2. 将所有电商订单（配送点）随机排序后，依次尝试插入到各条路线末尾，
         插入时估计行驶时间和配送点服务时间，检查容量约束。
    """
    # 构造网点字典，方便根据 Site_id 获取经纬度
    site_dict = {row['Site_id']: (row['Lat'], row['Lng']) for index, row in sites.iterrows()}
    
    # 构造配送点字典
    spot_dict = {row['Spot_id']: (row['Lat'], row['Lng']) for index, row in spots.iterrows()}
    
    # 构造电商订单列表（这里只处理电商订单）
    orders = []
    for index, row in ecommerce_orders.iterrows():
        spot_id = row['Spot_id']
        lat, lng = spot_dict[spot_id]
        # 电商订单配送：取货在网点（所有订单均可在 8:00 取到），这里只需要配送到消费者对应的配送点
        order_stop = Stop(location_id=spot_id, lat=lat, lng=lng, stop_type="delivery",
                          order_id=row['Order_id'], packages=row['Num'])
        orders.append(order_stop)
    # 随机打乱顺序，模拟无序订单
    random.shuffle(orders)
    
    # 为每个快递员创建一条路线，起始点为随机选取的网点
    courier_routes = {}
    for index, row in couriers.iterrows():
        courier_id = row['Courier_id']
        site_row = sites.sample(1).iloc[0]
        lat, lng = site_row['Lat'], site_row['Lng']
        start_stop = Stop(location_id=site_row['Site_id'], lat=lat, lng=lng, stop_type="site")
        # 起始网点默认为 08:00 出发，设定到达和离开时间均为0
        start_stop.arrival = 0
        start_stop.departure = 0
        courier_routes[courier_id] = Route(courier_id, start_stop)
    
    # 贪心插入：对每个订单，选择使路线增加时间最少的插入（这里仅在末尾插入）
    for order in orders:
        best_increase = float('inf')
        best_route = None
        for route in courier_routes.values():
            last_stop = route.stops[-1]
            dist = compute_distance(last_stop.lat, last_stop.lng, order.lat, order.lng)
            t_time = travel_time(dist)
            # 预计到达时间
            est_arrival = last_stop.departure + t_time
            # 检查容量（简化：当前载货量加上该订单包裹是否超过上限）
            if route.current_load + order.packages > MAX_CAPACITY:
                continue
            # 计算配送点的服务时间
            s_time = service_time(order.packages)
            new_departure = est_arrival + s_time
            increase = new_departure - route.total_time()
            if increase < best_increase:
                best_increase = increase
                best_route = route
        if best_route is not None:
            # 将订单插入到最佳路线的末尾
            last_stop = best_route.stops[-1]
            dist = compute_distance(last_stop.lat, last_stop.lng, order.lat, order.lng)
            t_time = travel_time(dist)
            arrival_time = last_stop.departure + t_time
            s_time = service_time(order.packages)
            departure_time = arrival_time + s_time
            order.arrival = arrival_time
            order.departure = departure_time
            best_route.stops.append(order)
            best_route.current_load += order.packages
    return courier_routes

# ============ 路径时间重计算 ============
def recalc_route_times(route):
    """
    根据路线中各站点之间的行驶时间和服务时间（配送点），重新计算到达和离开时间。
    这里简单处理，对于网点和商户（pickup）可设为0服务时间，配送点按公式计算。
    """
    for i, stop in enumerate(route.stops):
        if i == 0:
            # 起始点
            stop.arrival = 0
            stop.departure = 0
            continue
        prev_stop = route.stops[i-1]
        dist = compute_distance(prev_stop.lat, prev_stop.lng, stop.lat, stop.lng)
        t_time = travel_time(dist)
        arrival_time = prev_stop.departure + t_time
        # 如果有时间窗要求，可在此调整（如等待至 earliest）
        if arrival_time < stop.earliest:
            arrival_time = stop.earliest
        if stop.stop_type == "delivery":
            s_time = service_time(stop.packages)
        else:
            s_time = 0
        departure_time = arrival_time + s_time
        stop.arrival = arrival_time
        stop.departure = departure_time
    return route.stops[-1].departure  # 返回路线总耗时

# ============ 局部搜索：2-opt 交换 ============
def two_opt(route):
    """
    对单个路线应用 2-opt 交换，遍历所有可能的交换对，若交换后总耗时下降，则接受新路线。
    注意：实际场景需同时验证所有约束，这里仅以总时间作为优化目标。
    """
    best_route = copy.deepcopy(route)
    best_total_time = recalc_route_times(best_route)
    improved = True
    while improved:
        improved = False
        n = len(best_route.stops)
        for i in range(1, n - 2):
            for j in range(i + 1, n - 1):
                new_route = copy.deepcopy(best_route)
                # 反转 i 到 j 之间的顺序
                new_route.stops[i:j+1] = list(reversed(new_route.stops[i:j+1]))
                total_time = recalc_route_times(new_route)
                if total_time < best_total_time:
                    best_route = new_route
                    best_total_time = total_time
                    improved = True
        # 如果本次循环有改进，则继续寻找更优解
    return best_route

def local_search(courier_routes):
    """
    对每个快递员路线执行局部搜索（2-opt）
    """
    improved_routes = {}
    for courier_id, route in courier_routes.items():
        new_route = two_opt(route)
        improved_routes[courier_id] = new_route
    return improved_routes

# ============ save to CSV ===============
def save_schedule_to_csv(improved_routes, filename="submission.csv"):
    with open(filename, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["Courier_id", "Addr", "Arrival_time", "Departure", "Amount", "Order_id"])

        for courier_id, route in improved_routes.items():
            # 可根据需要对 stops 按到达时间排序，确保顺序正确
            route.stops.sort(key=lambda s: (s.arrival if s.arrival is not None else math.inf))

            for stop in route.stops:
                # 根据 stop_type 判断取/送货量
                if stop.stop_type in ("site", "shop"):
                    # 网点或商户 -> 取货
                    amount = stop.packages
                else:
                    # "delivery" -> 送货
                    amount = -stop.packages

                # 将 None 时间处理为 0 或根据需要处理
                arrival_time = int(round(stop.arrival)) if stop.arrival is not None else 0
                departure_time = int(round(stop.departure)) if stop.departure is not None else 0

                writer.writerow([
                    courier_id,         # Courier_id
                    stop.location_id,   # Addr
                    arrival_time,       # Arrival_time
                    departure_time,     # Departure_time
                    amount,             # Amount
                    stop.order_id       # Order_id
                ])

    print(f"Schedule successfully saved to {filename}")

# %%
# ============ 主函数 ============
def main():
    sites, spots, shops, ecommerce_orders, o2o_orders, couriers = read_data()
    print("数据读取完成。")
    # 构造初始解
    courier_routes = initial_solution(sites, spots, shops, ecommerce_orders, o2o_orders, couriers)
    print("初始解构造完成。")
    # 局部搜索优化
    improved_routes = local_search(courier_routes)
    print("局部搜索完成。")

    # 4. 计算并输出“总时间”或“最大时间”
    #    （也可结合服务时间、惩罚等，构造完整的目标函数）
    total_time = 0
    max_time = 0
    for courier_id, route in improved_routes.items():
        # 重新计算路线，以得到最后离开时间
        route_time = recalc_route_times(route)  
        total_time += route_time
        if route_time > max_time:
            max_time = route_time
    print(f"所有快递员路线的【总时间】为: {total_time} 分钟")
    print(f"所有快递员路线的【最大时间】为: {max_time} 分钟")
    
    # 5. 保存调度计划
    save_schedule_to_csv(improved_routes, "submission.csv")
    print("调度计划已保存至 submission.csv")

    # 6. 可视化或打印具体路线
    for courier_id, route in improved_routes.items():
        print(f"\n快递员 {courier_id} 路径：")
        for stop in route.stops:
            print(f"  站点: {stop.location_id} ({stop.stop_type}), "
                  f"到达: {stop.arrival}, 离开: {stop.departure}, "
                  f"订单: {stop.order_id}, 包裹数: {stop.packages}")
    
if __name__ == "__main__":
    main()
# Out:
# 数据读取完成。
# 初始解构造完成。
# 局部搜索完成。
# 所有快递员路线的【总时间】为: 200490.8759138169 分钟
# 所有快递员路线的【最大时间】为: 757.6331059033522 分钟
# Schedule successfully saved to submission.csv
# 调度计划已保存至 submission.csv
#
# 快递员 D0001 路径：
#   站点: A097 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B7982 (delivery), 到达: 10.681506708045104, 离开: 32.113183433200085, 订单: F7264, 包裹数: 30
#   站点: B3000 (delivery), 到达: 34.474229389173075, 离开: 55.90590611432806, 订单: F7225, 包裹数: 30
#   站点: B2581 (delivery), 到达: 58.59388772509207, 离开: 74.8188598854139, 订单: F7217, 包裹数: 14
#   站点: B0263 (delivery), 到达: 81.44494785608224, 离开: 104.93818986498917, 订单: F7202, 包裹数: 38
#   站点: B6752 (delivery), 到达: 109.5328728220419, 离开: 121.24107675454127, 订单: F7254, 包裹数: 5
#   站点: B9055 (delivery), 到达: 123.54055666105687, 离开: 137.54055666105688, 订单: F7274, 包裹数: 9
#   站点: B6889 (delivery), 到达: 141.4423227066261, 离开: 156.83462755203936, 订单: F7257, 包裹数: 12
#   站点: B5408 (delivery), 到达: 275.4731074180687, 离开: 284.71574810518797, 订单: F2808, 包裹数: 2
#
# 快递员 D0002 路径：
#   站点: A052 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B1691 (delivery), 到达: 2.2296970916394425, 离开: 30.85172071367488, 订单: F4273, 包裹数: 62
#   站点: B1869 (delivery), 到达: 38.386207116010425, 离开: 64.59941055160685, 订单: F5070, 包裹数: 50
#   站点: B3018 (delivery), 到达: 68.69475463322001, 离开: 85.69475463322001, 订单: F5077, 包裹数: 16
#   站点: B4444 (delivery), 到达: 168.67844913032297, 离开: 184.07075397573624, 订单: F4788, 包裹数: 12
#
# 快递员 D0003 路径：
#   站点: A048 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B
#   站点: B2897 (delivery), 到达: 204.7505487940351, 离开: 217.68780272722887, 订单: F4885, 包裹数: 7
#   站点: B3520 (delivery), 到达: 225.0804951513228, 离开: 238.01774908451657, 订单: F4893, 包裹数: 7
#   站点: B8076 (delivery), 到达: 247.4484807447105, 离开: 263.26513457110246, 订单: F1289, 包裹数: 13
#   站点: B2227 (delivery), 到达: 303.54071527453146, 离开: 324.69620969593495, 订单: F2887, 包裹数: 29
#
# 快递员 D0019 路径：
#   站点: A100 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B6343 (delivery), 到达: 9.827317204769864, 离开: 31.530610293259926, 订单: F3087, 包裹数: 31
#   站点: B1574 (delivery), 到达: 40.059982622695955, 离开: 61.215477044099465, 订单: F7536, 包裹数: 29
#   站点: B1765 (delivery), 到达: 68.24418994796821, 离开: 90.7370456325041, 订单: F7214, 包裹数: 34
#   站点: B7270 (delivery), 到达: 94.78278098075282, 离开: 119.68252972288522, 订单: F7260, 包裹数: 44
#   站点: B7627 (delivery), 到达: 205.0933962525521, 离开: 214.3360369396714, 订单: F2845, 包裹数: 2
#
# 快递员 D0020 路径：
#   站点: A007 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B6260 (delivery), 到达: 8.81093746049049, 离开: 33.483253033396494, 订单: F0372, 包裹数: 43
#   站点: B4829 (delivery), 到达: 37.36919116459768, 离开: 68.69408432677405, 订单: F0359, 包裹数: 77
#   站点: B8747 (delivery), 到达: 71.49791399592132, 离开: 88.8672308727743, 订单: F0395, 包裹数: 17
#   站点: B9104 (delivery), 到达: 207.08215485392077, 离开: 217.2783072766274, 订单: F7948, 包裹数: 3
#
# 快递员 D0021 路径：
#   站点: A097 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B5949 (delivery), 到达: 8.527731431554079, 离开: 20.87620065990361, 订单: F6023, 包裹数: 6
#   站点: B7322 (delivery), 到达: 27.813666485184626, 离开: 48.40212375330452, 订单: F7261, 包裹数: 27
#   站点: B4911 (delivery), 到达: 49.68350637057717, 离开: 74.58325511270957, 订单: F7239, 包裹数: 44
#   站点: B2639 (delivery), 到达: 79.2057249776737, 离开: 107.63647400539367, 订单: F7219, 包裹数: 61
#   站点: B9089 (delivery), 到达: 129.93026306893586, 离开: 139.17290375605515, 订单: F7275, 包裹数: 2
#
# 快递员 D0022 路径：
#   站点: A085 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B2010 (delivery), 到达: 8.732076916490854, 离开: 39.53905271761873, 订单: F6494, 包裹数: 74
#   站点: B7180 (delivery), 到达: 42.39274592232441, 离开: 68.81703120795297, 订单: F6527, 包裹数: 51
#   站点: B3261 (delivery), 到达: 186.51481022645206, 离开: 202.73978238677387, 订单: F8607, 包裹数: 14
#
# 快递员 D0023 路径：
#   站点: A056 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B6534 (delivery), 到达: 1.3656320050592803, 离开: 33.86108617479432, 订单: F4580, 包裹数: 84
#   站点: B0012 (delivery), 到达: 41.765906336178006, 离开: 68.19019162180655, 订单: F4543, 包裹数: 51
#   站点: B3638 (delivery), 到达: 107.50919016748685, 离开: 119.21739409998622, 订单: F5843, 包裹数: 5
#
# 快递员 D0024 路径：
#   站点: A037 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B
(site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B5563 (delivery), 到达: 3.7339491224800665, 离开: 36.55480460896718, 订单: F5903, 包裹数: 86
#   站点: B2783 (delivery), 到达: 38.1396059420506, 离开: 61.632847950957526, 订单: F5916, 包裹数: 38
#   站点: B0349 (delivery), 到达: 181.4967299902391, 离开: 198.4967299902391, 订单: F1023, 包裹数: 16
#
# 快递员 D0031 路径：
#   站点: A062 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B1132 (delivery), 到达: 10.22759508039553, 离开: 30.816052348515427, 订单: F4993, 包裹数: 27
#   站点: B3976 (delivery), 到达: 36.96764435712043, 离开: 66.33975957102831, 订单: F0968, 包裹数: 66
#   站点: B0142 (delivery), 到达: 74.19829458812845, 离开: 97.44658217902311, 订单: F4985, 包裹数: 37
#   站点: B0201 (delivery), 到达: 224.636622881178, 离开: 238.636622881178, 订单: F2696, 包裹数: 9
#   站点: B9004 (delivery), 到达: 367.29997193917046, 离开: 375.29997193917046, 订单: F2869, 包裹数: 1
#
# 快递员 D0032 路径：
#   站点: A033 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B2758 (delivery), 到达: 5.617885179313016, 离开: 30.742496976811125, 订单: F2968, 包裹数: 45
#   站点: B3844 (delivery), 到达: 33.43790485384978, 离开: 66.58039941279036, 订单: F2974, 包裹数: 88
#   站点: B8946 (delivery), 到达: 93.42002732709925, 离开: 105.12823125959862, 订单: F6231, 包裹数: 5
#
# 快递员 D0033 路径：
#   站点: A034 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B6292 (delivery), 到达: 8.589808592840345, 离开: 24.81478075316217, 订单: F3086, 包裹数: 14
#   站点: B1299 (delivery), 到达: 30.553825478627154, 离开: 50.553825478627154, 订单: F3035, 包裹数: 25
#   站点: B7750 (delivery), 到达: 52.09805940183785, 离开: 77.22267119933596, 订单: F3102, 包裹数: 45
#   站点: B6155 (delivery), 到达: 80.59209528459125, 离开: 104.8014679968898, 订单: F3083, 包裹数: 41
#   站点: B4744 (delivery), 到达: 118.03375436880432, 离开: 134.65270440742657, 订单: F3068, 包裹数: 15
#
# 快递员 D0034 路径：
#   站点: A051 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B6668 (delivery), 到达: 5.255006594003579, 离开: 21.479978754325405, 订单: F4263, 包裹数: 14
#   站点: B0699 (delivery), 到达: 29.486148180767046, 离开: 43.97298116127219, 订单: F4248, 包裹数: 10
#   站点: B2845 (delivery), 到达: 49.90889430819045, 离开: 64.85876867925664, 订单: F4253, 包裹数: 11
#   站点: B0877 (delivery), 到达: 70.74008139826915, 离开: 85.68995576933536, 订单: F4249, 包裹数: 11
#   站点: B2104 (delivery), 到达: 98.56229072113312, 离开: 117.94978529107128, 订单: F2164, 包裹数: 23
#   站点: B7433 (delivery), 到达: 191.8945879844569, 离开: 221.63322173816286, 订单: F7787, 包裹数: 68
#   站点: B0946 (delivery), 到达: 339.87296481495537, 离开: 349.11560550207463, 订单: F6314, 包裹数: 2
#
# 快递员 D0035 路径：
#   站点: A116 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B
(site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B7670 (delivery), 到达: 7.617345765125964, 离开: 34.45767543296752, 订单: F7667, 包裹数: 53
#   站点: B7764 (delivery), 到达: 37.43859332878957, 离开: 64.48400101383817, 订单: F4740, 包裹数: 54
#   站点: B2551 (delivery), 到达: 113.79105420216202, 离开: 136.0247421417761, 订单: F4647, 包裹数: 33
#
# 快递员 D0073 路径：
#   站点: A104 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B2727 (delivery), 到达: 3.94266058026977, 离开: 31.19125604155676, 订单: F7775, 包裹数: 55
#   站点: B5974 (delivery), 到达: 32.545666832962596, 离开: 63.177678068915185, 订单: F7783, 包裹数: 73
#   站点: B8710 (delivery), 到达: 162.55060293836556, 离开: 177.94290778377882, 订单: F0511, 包裹数: 12
#
# 快递员 D0074 路径：
#   站点: A068 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B3753 (delivery), 到达: 2.67898422854825, 离开: 32.417617982254214, 订单: F5535, 包裹数: 68
#   站点: B0279 (delivery), 到达: 38.78284287232844, 离开: 62.756508833338714, 订单: F5510, 包裹数: 40
#   站点: B8677 (delivery), 到达: 64.17869747765042, 离开: 83.87563593434948, 订单: F5565, 包裹数: 24
#   站点: B7509 (delivery), 到达: 163.35794927961575, 离开: 174.35794927961575, 订单: F2843, 包裹数: 4
#   站点: B4957 (delivery), 到达: 250.87373890899528, 离开: 261.8737389089953, 订单: F2798, 包裹数: 4
#
# 快递员 D0075 路径：
#   站点: A018 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B4880 (delivery), 到达: 7.124262532060267, 离开: 31.097928493070544, 订单: F1168, 包裹数: 40
#   站点: B1674 (delivery), 到达: 40.66193138587596, 离开: 60.95898992665431, 订单: F1135, 包裹数: 26
#   站点: B1323 (delivery), 到达: 76.48734580084351, 离开: 97.07580306896341, 订单: F8927, 包裹数: 27
#   站点: B1817 (delivery), 到达: 103.37832428068248, 离开: 125.87117996521837, 订单: F1137, 包裹数: 34
#   站点: B6899 (delivery), 到达: 132.17184374386636, 离开: 146.6586767243715, 订单: F1185, 包裹数: 10
#   站点: B5584 (delivery), 到达: 149.82478202191936, 离开: 160.020934444626, 订单: F1174, 包裹数: 3
#
# 快递员 D0076 路径：
#   站点: A016 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B1481 (delivery), 到达: 5.720429084626772, 离开: 29.69409504563705, 订单: F0945, 包裹数: 40
#   站点: B7448 (delivery), 到达: 35.72041559814509, 离开: 55.417354054844154, 订单: F0999, 包裹数: 24
#   站点: B3840 (delivery), 到达: 63.69386713236159, 离开: 85.12554385751658, 订单: F5014, 包裹数: 30
#   站点: B3267 (delivery), 到达: 95.10658473019346, 离开: 115.40364327097181, 订单: F0960, 包裹数: 26
#   站点: B3483 (delivery), 到达: 125.72589489631211, 离开: 143.80259172693414, 订单: F2459, 包裹数: 19
#
# 快递员 D0077 路径：
#   站点: A090 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B1508 (delivery), 到达: 5.574243910722233, 离开: 34.76101715561788, 订单: F6802, 包裹数: 65
#   站点: B7016 (delivery), 到达: 36.94855064471086, 离开: 64.79586996230259, 订单: F6838, 包裹数: 58
#   站点: B1652 (delivery), 到达: 148.5489572534376, 离开: 165.9182741302906, 订单: F8583, 包裹数: 17
#
# 快递员 D0078 路径：
#   站点: A072 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B0581 (delivery), 到达: 9.194571490659088, 离开: 38.381344735554734, 订单: F5811, 包裹数: 65
#   站点: B2495 (delivery), 到达: 46.60620038837793, 离开: 77.23821162433052, 订单: F8293, 包裹数: 73
#
# 快递员 D0079 路径：
#   站点: A117 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B6339 (delivery), 到达: 16.806836184843448, 离开: 30.806836184843448, 订单: F8794, 包裹数: 9
#   站点: B4823 (delivery), 到达: 43.13415526588183, 离开: 56.6194366401204, 订单: F8776, 包裹数: 8
#   站点: B5378 (delivery), 到达: 66.0887008781772, 离开: 85.15994815764749, 订单: F8783, 包裹数: 22
#   站点: B0544 (delivery), 到达: 88.25188616741015, 离开: 104.06853999380212, 订单: F3493, 包裹数: 13
#   站点: B8743 (delivery), 到达: 115.98313224558942, 离开: 136.5715895137093, 订单: F3649, 包裹数: 27
#   站点: B8470 (delivery), 到达: 147.854851738133, 离开: 158.05100416083963, 订单: F8990, 包裹数: 3
#   站点: B4105 (delivery), 到达: 169.79512081693537, 离开: 179.03776150405466, 订单: F3564, 包裹数: 2
#   站点: B2156 (delivery), 到达: 191.75976424642988, 离开: 209.8364610770519, 订单: F3525, 包裹数: 19
#   站点: B3769 (delivery), 到达: 238.12027667500746, 离开: 259.27577109641095, 订单: F3560, 包裹数: 29
#   站点: B6882 (delivery), 到达: 272.24536550740686, 离开: 285.73064688164544, 订单: F3618, 包裹数: 8
#
# 快递员 D0080 路径：
#   站点: A115 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B1269 (delivery), 到达: 1.575102815656117, 离开: 26.017324910879697, 订单: F8533, 包裹数: 42
#   站点: B3895 (delivery), 到达: 27.33579809860666, 离开: 52.23554684073906, 订单: F8539, 包裹数: 44
#   站点: B3086 (delivery), 到达: 53.99269327536311, 离开: 80.20589671095954, 订单: F8537, 包裹数: 50
#   站点: B8589 (delivery), 到达: 264.2196153426028, 离开: 275.2196153426028, 订单: F2931, 包裹数: 4
#
# 快递员 D0081 路径：
#   站点: A036 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B5498 (delivery), 到达: 2.2474966321931165, 离开: 29.08782630003467, 订单: F3308, 包裹数: 53
#   站点: B2697 (delivery), 到达: 31.191119212940396, 离开: 58.840622518752646, 订单: F3288, 包裹数: 57
#   站点: B3254 (delivery), 到达: 76.42519690589954, 离开: 97.29970477228709, 订单: F0959, 包裹数: 28
#
# 快递员 D0082 路径：
#   站点: A008 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B3021 (delivery), 到达: 11.964908103386234, 离开: 31.6618465600853, 订单: F0440, 包裹数: 24
#   站点: B2520 (delivery), 到达: 40.77110591145033, 离开: 55.25793889195546, 订单: F0434, 包裹数: 10
#   站点: B0094 (delivery), 到达: 84.91650603329046, 离开: 106.34818275844545, 订单: F0403, 包裹数: 30
#   站点: B6020 (delivery), 到达: 114.90843505021785, 离开: 131.13340721053967, 订单: F0479, 包裹数: 14
#   站点: B1642 (delivery), 到达: 136.86776779050373, 离开: 164.517271096316, 订单: F0422, 包裹数: 57
#   站点: B8832 (delivery), 到达: 171.0384334965466, 离开: 182.0384334965466, 订单: F0513, 包裹数: 4
#
# 快递员 D0083 路径：
#   站点: A083 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B7063 (delivery), 到达: 9.497220687168294, 离开: 24.88952553258156, 订单: F6438, 包裹数: 12
# ...
#   站点: B7216 (delivery), 到达: 150.03463804951332, 离开: 162.9718919827071, 订单: F4393, 包裹数: 7
#   站点: B0205 (delivery), 到达: 316.57120908551656, 离开: 325.8138497726358, 订单: F5238, 包裹数: 2
#
# 快递员 D0961 路径：
#   站点: A058 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B4170 (delivery), 到达: 20.204627453178215, 离开: 47.25003513822682, 订单: F3674, 包裹数: 54
#   站点: B5460 (delivery), 到达: 81.52967937816791, 离开: 114.18831275004658, 订单: F0869, 包裹数: 85
#
# 快递员 D0962 路径：
#   站点: A044 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B2648 (delivery), 到达: 3.638883172133875, 离开: 20.638883172133873, 订单: F3942, 包裹数: 16
#   站点: B5868 (delivery), 到达: 26.889303496429637, 离开: 39.23777272477917, 订单: F3958, 包裹数: 6
#   站点: B1761 (delivery), 到达: 53.04650453053744, 离开: 72.7434429872365, 订单: F3938, 包裹数: 24
#   站点: B2003 (delivery), 到达: 77.61361202729113, 离开: 95.69030885791315, 订单: F3940, 包裹数: 19
#   站点: B2507 (delivery), 到达: 329.54825245358666, 离开: 360.18026368953923, 订单: F2746, 包裹数: 73
#   站点: B7656 (delivery), 到达: 405.0775968558592, 离开: 414.3202375429785, 订单: F2846, 包裹数: 2
#
# 快递员 D0963 路径：
#   站点: A079 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B8165 (delivery), 到达: 14.568079213193041, 离开: 38.77745192549159, 订单: F5883, 包裹数: 41
#   站点: B0795 (delivery), 到达: 50.56287204070783, 离开: 84.95674895410596, 订单: F6166, 包裹数: 96
#   站点: B8971 (delivery), 到达: 225.23175168358497, 离开: 235.4279041062916, 订单: F7945, 包裹数: 3
#
# 快递员 D0964 路径：
#   站点: A013 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B3205 (delivery), 到达: 13.165058425133765, 离开: 43.620902547849475, 订单: F3995, 包裹数: 72
#   站点: B6753 (delivery), 到达: 54.57189251027496, 离开: 84.31052626398092, 订单: F6524, 包裹数: 68
#
# 快递员 D0965 路径：
#   站点: A027 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B0810 (delivery), 到达: 12.885436442694894, 离开: 41.885436442694896, 订单: F2434, 包裹数: 64
#   站点: B8421 (delivery), 到达: 50.55544765137993, 离开: 68.63214448200195, 订单: F6447, 包裹数: 19
#   站点: B5344 (delivery), 到达: 73.90087468093157, 离开: 98.80062342306397, 订单: F0982, 包裹数: 44
#   站点: B8146 (delivery), 到达: 162.84441839613496, 离开: 178.6610722225269, 订单: F0809, 包裹数: 13
#
# 快递员 D0966 路径：
#   站点: A001 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B5674 (delivery), 到达: 9.801740985576624, 离开: 40.25758510829233, 订单: F3726, 包裹数: 72
#   站点: B8953 (delivery), 到达: 105.88538508190796, 离开: 134.88538508190794, 订单: F7054, 包裹数: 64
#   站点: B5269 (delivery), 到达: 219.8387830776341, 离开: 230.8387830776341, 订单: F2909, 包裹数: 4
#
# 快递员 D0967 路径：
#   站点: A050 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B8749 (delivery), 到达: 11.859652938398401, 离开: 34.8596529383984, 订单: F2137, 包裹数: 36
#   站点: B5222 (delivery), 到达: 67.51817855294547, 离开: 100.66067311188604, 订单: F4064, 包裹数: 88
#   站点: B4433 (delivery), 到达: 158.76692270865522, 离开: 175.76692270865522, 订单: F4508, 包裹数: 16
#
# 快递员 D0968 路径：
#   站点: A011 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B3789 (delivery), 到达: 9.136541761873072, 离开: 41.63199593160812, 订单: F6749, 包裹数: 84
#   站点: B1203 (delivery), 到达: 51.634491121048285, 离开: 78.26779877383223, 订单: F8287, 包裹数: 52
#   站点: B1711 (delivery), 到达: 287.3842105209909, 离开: 298.3842105209909, 订单: F7373, 包裹数: 4
#
# 快递员 D0969 路径：
#   站点: A066 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B2760 (delivery), 到达: 6.936839681513372, 离开: 29.17052762112746, 订单: F5281, 包裹数: 33
#   站点: B8553 (delivery), 到达: 166.81289254282552, 离开: 199.4715259147042, 订单: F4090, 包裹数: 85
#   站点: B8604 (delivery), 到达: 324.35169067650213, 离开: 343.09941776136964, 订单: F8704, 包裹数: 21
#
# 快递员 D0970 路径：
#   站点: A099 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B4260 (delivery), 到达: 144.708210914081, 离开: 174.62808250283524, 订单: F0145, 包裹数: 69
#   站点: B6660 (delivery), 到达: 201.29356762787825, 离开: 230.8496259434956, 订单: F0635, 包裹数: 67
#   站点: B8034 (delivery), 到达: 483.275924069256, 离开: 494.275924069256, 订单: F4970, 包裹数: 4
#
# 快递员 D0971 路径：
#   站点: A124 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B0944 (delivery), 到达: 22.611375848587357, 离开: 51.61137584858736, 订单: F2001, 包裹数: 64
#   站点: B2325 (delivery), 到达: 68.58768622005114, 离开: 92.32268021524634, 订单: F4555, 包裹数: 39
#   站点: B4203 (delivery), 到达: 122.29533216100194, 离开: 142.29533216100194, 订单: F9120, 包裹数: 25
#   站点: B8275 (delivery), 到达: 148.90298394142147, 离开: 162.90298394142147, 订单: F9164, 包裹数: 9
#   站点: B1495 (delivery), 到达: 244.94357381557973, 离开: 255.13972623828636, 订单: F6604, 包裹数: 3
#
# 快递员 D0972 路径：
#   站点: A035 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B2383 (delivery), 到达: 4.180028013185809, 离开: 32.991789812767124, 订单: F3160, 包裹数: 63
#   站点: B1862 (delivery), 到达: 42.01127100256756, 离开: 66.45349309779114, 订单: F3150, 包裹数: 42
#   站点: B4085 (delivery), 到达: 84.27329239151304, 离开: 106.24385513999019, 订单: F3185, 包裹数: 32
#   站点: B1461 (delivery), 到达: 118.30108892679796, 离开: 128.49724134950458, 订单: F0534, 包裹数: 3
#
# 快递员 D0973 路径：
#   站点: A008 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B3382 (delivery), 到达: 7.762132428121452, 离开: 24.381082466743706, 订单: F0446, 包裹数: 15
#   站点: B4150 (delivery), 到达: 93.858551202037, 离开: 124.4905624379896, 订单: F9119, 包裹数: 73
#   站点: B8636 (delivery), 到达: 132.36742193140861, 离开: 146.85425491191376, 订单: F2422, 包裹数: 10
#   站点: B7755 (delivery), 到达: 153.63926732940044, 离开: 176.8875549202951, 订单: F9156, 包裹数: 37
#   站点: B3202 (delivery), 到达: 228.68312478337876, 离开: 240.39132871587813, 订单: F8944, 包裹数: 5
#
# 快递员 D0974 路径：
#   站点: A095 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B7969 (delivery), 到达: 1.101442581696044, 离开: 29.144879825301867, 订单: F7157, 包裹数: 59
#   站点: B4144 (delivery), 到达: 38.25485551169095, 离开: 56.331552342312975, 订单: F7108, 包裹数: 19
#   站点: B5055 (delivery), 到达: 78.3467440855863, 离开: 100.31730683406343, 订单: F7123, 包裹数: 32
#   站点: B2093 (delivery), 到达: 115.4311646766566, 离开: 133.84757254165535, 订单: F1044, 包裹数: 20
#   站点: B5253 (delivery), 到达: 140.75388203723966, 离开: 154.23916341147824, 订单: F1080, 包裹数: 8
#   站点: B9048 (delivery), 到达: 163.28683339537574, 离开: 171.28683339537574, 订单: F3274, 包裹数: 1
#
# 快递员 D0975 路径：
#   站点: A113 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B5730 (delivery), 到达: 76.24934734559952, 离开: 107.91393059754628, 订单: F4303, 包裹数: 79
#   站点: B0503 (delivery), 到达: 116.71366931289359, 离开: 143.34697696567753, 订单: F1896, 包裹数: 52
#   站点: B2711 (delivery), 到达: 284.12136282546345, 离开: 297.0586167586572, 订单: F1235, 包裹数: 7
#   站点: B1864 (delivery), 到达: 314.2291607478866, 离开: 323.4718014350059, 订单: F1228, 包裹数: 2
#
# 快递员 D0976 路径：
#   站点: A024 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B0823 (delivery), 到达: 8.026516924934162, 离开: 39.69110017688093, 订单: F1902, 包裹数: 79
#   站点: B0734 (delivery), 到达: 43.471189530782624, 离开: 68.14350510368863, 订单: F1901, 包裹数: 43
#   站点: B2096 (delivery), 到达: 139.89953525056148, 离开: 157.62745731191933, 订单: F1045, 包裹数: 18
#
# 快递员 D0977 路径：
#   站点: A101 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B1286 (delivery), 到达: 3.182799349093835, 离开: 35.348954763506086, 订单: F0619, 包裹数: 82
#   站点: B0437 (delivery), 到达: 39.39324242898369, 离开: 64.7402323783595, 订单: F3869, 包裹数: 46
#   站点: B5229 (delivery), 到达: 171.62984568464188, 离开: 187.02215053005514, 订单: F5323, 包裹数: 12
#
# 快递员 D0978 路径：
#   站点: A032 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B8229 (delivery), 到达: 63.37037766595878, 离开: 91.01988097177103, 订单: F4533, 包裹数: 57
#   站点: B7085 (delivery), 到达: 141.12407569111798, 离开: 164.6173177000249, 订单: F8679, 包裹数: 38
#   站点: B0361 (delivery), 到达: 218.3411722711573, 离开: 242.78339436638086, 订单: F2512, 包裹数: 42
#   站点: B3744 (delivery), 到达: 278.4636717036753, 离开: 288.6598241263819, 订单: F2569, 包裹数: 3
#
# 快递员 D0979 路径：
#   站点: A072 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B5241 (delivery), 到达: 4.311007642677965, 离开: 31.760951963321613, 订单: F5857, 包裹数: 56
#   站点: B7977 (delivery), 到达: 33.282643426295216, 离开: 56.282643426295216, 订单: F5880, 包裹数: 36
#   站点: B0188 (delivery), 到达: 59.64548593968651, 离开: 83.61915190069678, 订单: F5807, 包裹数: 40
#   站点: B2391 (delivery), 到达: 139.38450942447943, 离开: 151.73297865282896, 订单: F0433, 包裹数: 6
#
# 快递员 D0980 路径：
#   站点: A014 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B0706 (delivery), 到达: 2.7801822675420804, 离开: 27.452497840448082, 订单: F0858, 包裹数: 43
#   站点: B6620 (delivery), 到达: 35.81050823054462, 离开: 62.85591591559322, 订单: F1959, 包裹数: 54
#   站点: B4185 (delivery), 到达: 133.58605533031522, 离开: 157.07929733922214, 订单: F3401, 包裹数: 38
#   站点: B7591 (delivery), 到达: 206.97417692142366, 离开: 217.97417692142366, 订单: F3628, 包裹数: 4
#
# 快递员 D0981 路径：
#   站点: A072 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B4176 (delivery), 到达: 4.2895317352954585, 离开: 38.064520875171766, 订单: F5849, 包裹数: 92
#   站点: B0373 (delivery), 到达: 45.35239514529736, 离开: 71.13700483612388, 订单: F5810, 包裹数: 48
#
# 快递员 D0982 路径：
#   站点: A037 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B1058 (delivery), 到达: 0.8513971130460646, 离开: 26.851397113046065, 订单: F3350, 包裹数: 49
#   站点: B6498 (delivery), 到达: 38.50349848514593, 离开: 60.474061233623075, 订单: F3439, 包裹数: 32
#   站点: B6652 (delivery), 到达: 67.60171449528713, 离开: 83.82668665560895, 订单: F3440, 包裹数: 14
#   站点: B1609 (delivery), 到达: 86.51458169894582, 离开: 106.21152015564488, 订单: F3358, 包裹数: 24
#   站点: B5742 (delivery), 到达: 112.14316509624805, 离开: 130.5595729612468, 订单: F3428, 包裹数: 20
#
# 快递员 D0983 路径：
#   站点: A070 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B3921 (delivery), 到达: 97.20235186994236, 离开: 130.66285081145776, 订单: F0144, 包裹数: 90
#   站点: B8853 (delivery), 到达: 151.1834099663131, 离开: 176.75037376751624, 订单: F2139, 包裹数: 47
#
# 快递员 D0984 路径：
#   站点: A094 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B5686 (delivery), 到达: 3.8541223916679934, 离开: 27.58911638686319, 订单: F7030, 包裹数: 39
#   站点: B0485 (delivery), 到达: 33.75799193977064, 离开: 67.37616798227901, 订单: F7177, 包裹数: 91
#   站点: B8567 (delivery), 到达: 234.2596410365439, 离开: 248.2596410365439, 订单: F2672, 包裹数: 9
#   站点: B6429 (delivery), 到达: 259.15117421569516, 离开: 267.15117421569516, 订单: F2628, 包裹数: 1
#
# 快递员 D0985 路径：
#   站点: A081 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B4868 (delivery), 到达: 11.21456873011861, 离开: 42.87915198206538, 订单: F0108, 包裹数: 79
#   站点: B0517 (delivery), 到达: 50.49206740043165, 离开: 78.53550464403747, 订单: F4034, 包裹数: 59
#
# 快递员 D0986 路径：
#   站点: A046 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B2597 (delivery), 到达: 1.3713638112685682, 离开: 34.98953985377693, 订单: F4048, 包裹数: 91
#   站点: B0745 (delivery), 到达: 37.124893729263746, 离开: 51.61172670976889, 订单: F4035, 包裹数: 10
#   站点: B8654 (delivery), 到达: 56.14912258943939, 离开: 79.1491225894394, 订单: F5117, 包裹数: 36
#
# 快递员 D0987 路径：
#   站点: A108 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B2739 (delivery), 到达: 7.2068896004350185, 离开: 32.55387954981082, 订单: F8044, 包裹数: 46
#   站点: B3712 (delivery), 到达: 52.63986187234087, 离开: 73.51436973872842, 订单: F8619, 包裹数: 28
#   站点: B1909 (delivery), 到达: 93.45268581431208, 离开: 121.88343484203205, 订单: F0538, 包裹数: 61
#   站点: B3764 (delivery), 到达: 209.25488935060346, 离开: 220.25488935060346, 订单: F2570, 包裹数: 4
#   站点: B7043 (delivery), 到达: 231.31130620967448, 离开: 239.31130620967448, 订单: F2640, 包裹数: 1
#
# 快递员 D0988 路径：
#   站点: A045 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B2477 (delivery), 到达: 1.7210355491770652, 离开: 32.17687967189278, 订单: F3988, 包裹数: 72
#   站点: B7031 (delivery), 到达: 34.40489330453201, 离开: 58.13988729972721, 订单: F4015, 包裹数: 39
#   站点: B6883 (delivery), 到达: 110.37624993101443, 离开: 131.25075779740197, 订单: F3689, 包裹数: 28
#   站点: B2830 (delivery), 到达: 134.23789241263603, 离开: 142.23789241263603, 订单: F6869, 包裹数: 1
#
# 快递员 D0989 路径：
#   站点: A044 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B8519 (delivery), 到达: 5.591107414473449, 离开: 20.54098178553965, 订单: F3972, 包裹数: 11
#   站点: B0289 (delivery), 到达: 26.79022579890053, 离开: 46.79022579890053, 订单: F3932, 包裹数: 25
#   站点: B4929 (delivery), 到达: 50.355921682014724, 离开: 68.08384374337258, 订单: F3954, 包裹数: 18
#   站点: B8476 (delivery), 到达: 71.5856429430403, 离开: 90.97313751297845, 订单: F3970, 包裹数: 23
#   站点: B0047 (delivery), 到达: 97.68962748393984, 离开: 116.10603534893858, 订单: F3930, 包裹数: 20
#   站点: B3192 (delivery), 到达: 120.59712133229975, 离开: 131.59712133229976, 订单: F3947, 包裹数: 4
#   站点: B9131 (delivery), 到达: 199.0815956034315, 离开: 222.57483761233843, 订单: F0613, 包裹数: 38
#
# 快递员 D0990 路径：
#   站点: A010 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B2305 (delivery), 到达: 11.872734037936711, 离开: 44.36818820767175, 订单: F0092, 包裹数: 84
#   站点: B5867 (delivery), 到达: 86.80151485673144, 离开: 113.84692254178005, 订单: F7032, 包裹数: 54
#
# 快递员 D0991 路径：
#   站点: A018 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B2562 (delivery), 到达: 7.370456834249539, 离开: 23.595428994571364, 订单: F1145, 包裹数: 14
#   站点: B4065 (delivery), 到达: 42.35369313413577, 离开: 57.30356750520197, 订单: F8954, 包裹数: 11
#   站点: B2251 (delivery), 到达: 115.40908834911703, 离开: 140.53370014661513, 订单: F2347, 包裹数: 45
#   站点: B3593 (delivery), 到达: 178.83153434185414, 离开: 207.2622833695741, 订单: F2044, 包裹数: 61
#   站点: B1488 (delivery), 到达: 357.00867194870915, 离开: 371.00867194870915, 订单: F3512, 包裹数: 9
#
# 快递员 D0992 路径：
#   站点: A083 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B2589 (delivery), 到达: 6.27659041924282, 离开: 25.973528875941884, 订单: F6403, 包裹数: 24
#   站点: B4247 (delivery), 到达: 36.77324634403953, 离开: 64.22319066468317, 订单: F6420, 包裹数: 56
#   站点: B5341 (delivery), 到达: 72.35988450106275, 离开: 87.30975887212895, 订单: F2470, 包裹数: 11
#   站点: B7563 (delivery), 到达: 91.43201646994928, 离开: 106.38189084101548, 订单: F2495, 包裹数: 11
#   站点: B6504 (delivery), 到达: 123.11318923844166, 离开: 145.0837519869188, 订单: F4385, 包裹数: 32
#   站点: B7022 (delivery), 到达: 195.14445660124716, 离开: 207.4929258295967, 订单: F5737, 包裹数: 6
#
# 快递员 D0993 路径：
#   站点: A064 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B3273 (delivery), 到达: 17.395284222653753, 离开: 52.244907335852346, 订单: F5162, 包裹数: 99
#   站点: B8265 (delivery), 到达: 57.6220746114257, 离开: 81.59574057243597, 订单: F3799, 包裹数: 40
#
# 快递员 D0994 路径：
#   站点: A071 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B5027 (delivery), 到达: 88.51833555966891, 离开: 117.33009735925023, 订单: F7027, 包裹数: 63
#   站点: B8780 (delivery), 到达: 184.40892585394192, 离开: 208.8511479491655, 订单: F4834, 包裹数: 42
#   站点: B3343 (delivery), 到达: 262.91352383919866, 离开: 284.06901826060215, 订单: F3388, 包裹数: 29
#   站点: B6122 (delivery), 到达: 350.768761763908, 离开: 363.11723099225753, 订单: F3604, 包裹数: 6
#
# 快递员 D0995 路径：
#   站点: A105 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B8833 (delivery), 到达: 28.39418485051077, 离开: 55.0274925032947, 订单: F8274, 包裹数: 52
#   站点: B2646 (delivery), 到达: 123.23994324273929, 离开: 153.51839256226836, 订单: F4281, 包裹数: 71
#   站点: B1981 (delivery), 到达: 155.91878000476723, 离开: 173.28809688162022, 订单: F6805, 包裹数: 17
#
# 快递员 D0996 路径：
#   站点: A042 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B6906 (delivery), 到达: 1.3026928459598806, 离开: 29.150012163551608, 订单: F3850, 包裹数: 58
#   站点: B6610 (delivery), 到达: 63.2475971888124, 离开: 75.59606641716194, 订单: F0155, 包裹数: 6
#   站点: B2399 (delivery), 到达: 76.35189002058675, 离开: 104.39532726419257, 订单: F0140, 包裹数: 59
#   站点: B6158 (delivery), 到达: 193.94844651388365, 离开: 210.94844651388365, 订单: F1855, 包裹数: 16
#
# 快递员 D0997 路径：
#   站点: A070 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B5980 (delivery), 到达: 86.87904032156237, 离开: 113.51234797434631, 订单: F3727, 包裹数: 52
#   站点: B7556 (delivery), 到达: 164.42392997780692, 离开: 192.07343328361918, 订单: F4243, 包裹数: 57
#   站点: B0160 (delivery), 到达: 278.19236075962584, 离开: 299.62403748478084, 订单: F1770, 包裹数: 30
#
# 快递员 D0998 路径：
#   站点: A084 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B5302 (delivery), 到达: 18.643762068933558, 离开: 46.09370638957721, 订单: F7588, 包裹数: 56
#   站点: B4578 (delivery), 到达: 52.57098869860661, 离开: 84.23557195055338, 订单: F0629, 包裹数: 79
#   站点: B5696 (delivery), 到达: 223.84126296881252, 离开: 235.5494669013119, 订单: F5972, 包裹数: 5
#
# 快递员 D0999 路径：
#   站点: A029 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B1891 (delivery), 到达: 1.6749414254686603, 离开: 24.42318077476751, 订单: F2444, 包裹数: 35
#   站点: B0983 (delivery), 到达: 31.69882310955179, 离开: 56.8234349070499, 订单: F2435, 包裹数: 45
#   站点: B0564 (delivery), 到达: 62.36027869545174, 离开: 84.59396663506583, 订单: F2433, 包裹数: 33
#   站点: B2378 (delivery), 到达: 92.73559522939718, 离开: 112.73559522939718, 订单: F2448, 包裹数: 25
#
# 快递员 D1000 路径：
#   站点: A072 (site), 到达: 0, 离开: 0, 订单: None, 包裹数: 0
#   站点: B1060 (delivery), 到达: 5.236374446496171, 离开: 34.79243276211352, 订单: F5817, 包裹数: 67
#   站点: B6062 (delivery), 到达: 36.051811444675025, 离开: 63.300406905962014, 订单: F6208, 包裹数: 55
#   站点: B5655 (delivery), 到达: 73.5485895942531, 离开: 91.27651165561096, 订单: F6206, 包裹数: 18
